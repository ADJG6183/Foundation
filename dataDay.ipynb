# %% [markdown]
# # DAY 1 - Mastering Data Pre-processing

# %%
# DAY 1 - Mastering Data Pre-processing
import kagglehub
import pandas as pd
import numpy as np
import matplotlib.pyplot  as plt

# %% [markdown]
# Loading the dataset and visualizing

# %%
df = pd.read_csv('social_media_sleep_stress_productivity_11000.csv')
df.head()
# Out:
#    user_id  age  daily_screen_time_hours  social_media_hours  sleep_hours  \
# 0        1   44                     2.39                1.93         8.46
# 1        2   30                     7.22                5.24         7.34
# 2        3   23                     2.56                4.64         4.69
# 3        4   36                     8.75                4.89         5.05
# 4        5   34                    10.96                2.77         7.12
#
#    exercise_minutes  study_work_hours  productivity_score stress_level  \
# 0                61              3.73               33.86          Low
# 1                28              6.80               85.32          Low
# 2                 8              4.47               60.07         High
# 3                53              9.53               36.46       Medium
# 4                83              7.01               32.93       Medium
#
#     platform
# 0    YouTube
# 1    YouTube
# 2    YouTube
# 3   LinkedIn
# 4  Instagram

# %%
df.info()
print(df.isnull().sum())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 11000 entries, 0 to 10999
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   user_id                  11000 non-null  int64
#  1   age                      11000 non-null  int64
#  2   daily_screen_time_hours  11000 non-null  float64
#  3   social_media_hours       11000 non-null  float64
#  4   sleep_hours              11000 non-null  float64
#  5   exercise_minutes         11000 non-null  int64
#  6   study_work_hours         11000 non-null  float64
#  7   productivity_score       11000 non-null  float64
#  8   stress_level             11000 non-null  str
#  9   platform                 11000 non-null  str
# dtypes: float64(5), int64(3), str(2)
# memory usage: 859.5 KB
# user_id                    0
# age                        0
# daily_screen_time_hours    0
# social_media_hours         0
# sleep_hours                0
# ...

# %%
print(df.columns)
print(len(df))
print(df['age'])
print(df['age': 44])

df = ['age'].hist()
print(histogram)
# Out:
# Index(['user_id', 'age', 'daily_screen_time_hours', 'social_media_hours',
#        'sleep_hours', 'exercise_minutes', 'study_work_hours',
#        'productivity_score', 'stress_level', 'platform'],
#       dtype='str')
# 11000
# 0        44
# 1        30
# 2        23
# 3        36
# 4        34
#          ..
# 10995    27
# 10996    35
# 10997    38
# 10998    45
# 10999    45
# Name: age, Length: 11000, dtype: int64
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 4
#       1 print(df.columns)
#       2 print(len(df))
#       3 print(df['age'])
# ----> 4 print(df['age': 44])
#       5
#       6 df = ['age'].hist()
#       7 print(histogram)
#
# File ~/Desktop/ML Pipeline/.venv/lib/python3.11/site-packages/pandas/core/frame.py:4361, in DataFrame.__getitem__(self, key)
#    4357                 return self._getitem_multilevel(key)
#    4358
# ...
